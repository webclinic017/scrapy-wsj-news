# %%
import sys
import os
import requests
import datetime
from pathlib import Path
import talib
import sqlite3 as sqlite3
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf
import matplotlib.font_manager as fm
import matplotlib.dates as mdates
import json
from matplotlib import font_manager as fm, rcParams
from mplfinance.original_flavor import candlestick_ohlc
from scipy import stats
# Out:
# d:\pycharmprojects\scrapy-001\venv\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# d:\pycharmprojects\scrapy-001\venv\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# d:\pycharmprojects\scrapy-001\venv\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
codes = ['00001.00', '02083.00', '01067.00', '00011.07', '00011.08', '00011.09', '00011.12', '00011.13', '00011.14', '02007.00', '02008.00']
index = ['indexName', 'indexReturn-ytd', 'indexReturn-1m', 'indexReturn-3m', 'indexReturn-6m', 'indexReturn-1y', 'indexReturn-3y', 'indexReturn-5y']
df = pd.DataFrame(columns=index)

for code in codes:
    url = f'https://www.hsi.com.hk/data/schi/indexes/{code}/chart-rebased.json'
    data = requests.get(url).content.decode('utf8')
    data = "".join(data.split()).strip()
    data = json.loads(data)
    # 注入數據
    df.loc[len(df)] = [data[k] for k in index]
df
# Out:
#           indexName indexReturn-ytd indexReturn-1m indexReturn-3m  \
# 0              恒生指数           0.95%         -4.55%         -5.55%
# 1            恒生科技指数         -11.80%         -7.58%        -10.96%
# 2          恒生高股息率指数           4.90%         -3.59%        -10.25%
# 3     恒生综合行业指数-公用事业          10.59%          1.31%          1.56%
# 4      恒生综合行业指数-金融业          -0.92%         -4.90%         -8.32%
# 5    恒生综合行业指数-地产建筑业           2.12%         -4.30%         -9.40%
# 6   恒生综合行业指数-非必需性消费           4.70%         -3.71%         -1.51%
# 7    恒生综合行业指数-必需性消费         -10.79%         -5.80%         -6.32%
# 8    恒生综合行业指数-医疗保健业          16.60%         -0.22%         12.24%
# 9        恒生中国内地银行指数           2.91%         -6.56%        -11.27%
# 10       恒生中国内地地产指数          -6.45%         -7.40%        -16.35%
#
#    indexReturn-6m indexReturn-1y indexReturn-3y indexReturn-5y
# 0          -7.26%          9.57%         -1.86%         26.84%
# 1         -20.72%          8.34%         53.32%        127.24%
# 2          -1.98%         15.88%         -8.82%         15.36%
# 3           6.63%         17.51%         -6.30%          9.20%
# 4         -10.38%          9.50%         -7.09%         19.97%
# 5          -5.54%         -0.84%         -4.46%         28.59%
# 6          -1.77%         50.35%         38.31%         84.17%
# 7         -15.94%          1.90%         22.76%         75.15%
# 8           9.49%         33.48%         49.43%        167.04%
# 9          -6.60%          4.52%         -3.76%         14.77%
# 10        -15.93%        -16.98%         -5.70%         85.61%
