# %%
import sys
import os
import requests
import datetime
from pathlib import Path
import talib
import sqlite3 as sqlite3
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf
import matplotlib.font_manager as fm
import matplotlib.dates as mdates
import json
from matplotlib import font_manager as fm, rcParams
from mplfinance.original_flavor import candlestick_ohlc
from scipy import stats

# %%
codes = ['00001.00', '02083.00', '01067.00', '00011.07', '00011.08', '00011.09', '00011.12', '00011.13', '00011.14', '02007.00', '02008.00']
index = ['indexName', 'indexReturn-ytd', 'indexReturn-1m', 'indexReturn-3m', 'indexReturn-6m', 'indexReturn-1y', 'indexReturn-3y', 'indexReturn-5y']
df = pd.DataFrame(columns=index)

for code in codes:
    url = f'https://www.hsi.com.hk/data/schi/indexes/{code}/chart-rebased.json'
    data = requests.get(url).content.decode('utf8')
    data = "".join(data.split()).strip()
    data = json.loads(data)
    # 注入數據
    df.loc[len(df)] = [data[k] for k in index]
df
# Out:
#           indexName indexReturn-ytd indexReturn-1m indexReturn-3m  \
# 0              恒生指数           1.04%         -4.60%         -3.45%
# 1            恒生科技指数         -10.82%         -5.97%         -6.53%
# 2          恒生高股息率指数           4.17%         -8.90%         -9.04%
# 3     恒生综合行业指数-公用事业           7.43%         -3.80%         -0.12%
# 4      恒生综合行业指数-金融业          -0.72%         -5.89%         -7.68%
# 5    恒生综合行业指数-地产建筑业           3.39%         -6.25%         -6.21%
# 6   恒生综合行业指数-非必需性消费           8.29%          1.25%          7.39%
# 7    恒生综合行业指数-必需性消费         -10.31%         -6.24%         -3.48%
# 8    恒生综合行业指数-医疗保健业          14.88%         -2.80%         16.12%
# 9        恒生中国内地银行指数           2.79%         -8.56%        -10.41%
# 10       恒生中国内地地产指数          -5.69%        -11.65%        -13.18%
#
#    indexReturn-6m indexReturn-1y indexReturn-3y indexReturn-5y
# 0          -2.55%          6.76%         -3.54%         29.04%
# 1         -13.33%         -2.88%         50.02%        132.64%
# 2           0.14%         10.78%        -10.28%         16.06%
# 3           3.85%         12.04%         -7.93%          7.45%
# 4          -6.21%          5.95%         -8.26%         22.20%
# 5           0.63%         -2.93%         -6.04%         32.48%
# 6           3.88%         52.56%         39.21%         93.90%
# 7         -14.06%          2.41%         20.40%         72.95%
# 8          14.61%         24.90%         42.44%        159.29%
# 9          -2.74%          1.77%         -6.56%         16.07%
# 10         -6.55%        -19.89%        -10.13%         87.74%
