# %%
import sys
import os
import requests
import datetime
from pathlib import Path
import talib
import sqlite3 as sqlite3
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf
import matplotlib.font_manager as fm
import matplotlib.dates as mdates
import json
from matplotlib import font_manager as fm, rcParams
from mplfinance.original_flavor import candlestick_ohlc
from scipy import stats

# %%
codes = ['00001.00', '02083.00', '01067.00', '00011.07', '00011.08', '00011.09', '00011.12', '00011.13', '00011.14', '02007.00', '02008.00']
index = ['indexName', 'indexReturn-ytd', 'indexReturn-1m', 'indexReturn-3m', 'indexReturn-6m', 'indexReturn-1y', 'indexReturn-3y', 'indexReturn-5y']
df = pd.DataFrame(columns=index)

for code in codes:
    url = f'https://www.hsi.com.hk/data/schi/indexes/{code}/chart-rebased.json'
    data = requests.get(url).content.decode('utf8')
    data = "".join(data.split()).strip()
    data = json.loads(data)
    # 注入數據
    df.loc[len(df)] = [data[k] for k in index]
df
# Out:
#           indexName indexReturn-ytd indexReturn-1m indexReturn-3m  \
# 0              恒生指数          -3.81%         -7.47%         -7.63%
# 1            恒生科技指数         -20.52%        -15.15%        -18.61%
# 2          恒生高股息率指数           1.23%         -5.36%        -10.84%
# 3     恒生综合行业指数-公用事业          14.75%          5.97%          7.26%
# 4      恒生综合行业指数-金融业          -2.06%         -3.41%         -6.77%
# 5    恒生综合行业指数-地产建筑业          -4.55%         -9.92%        -13.42%
# 6   恒生综合行业指数-非必需性消费           2.99%         -4.70%          0.53%
# 7    恒生综合行业指数-必需性消费         -14.77%         -6.78%         -6.85%
# 8    恒生综合行业指数-医疗保健业           4.39%        -12.34%         -4.53%
# 9        恒生中国内地银行指数           1.23%         -5.21%         -8.91%
# 10       恒生中国内地地产指数         -17.95%        -16.10%        -24.24%
#
#    indexReturn-6m indexReturn-1y indexReturn-3y indexReturn-5y
# 0         -10.62%          7.10%         -5.35%         20.50%
# 1         -33.86%         -8.17%         48.90%         98.99%
# 2          -2.84%         12.93%        -12.30%         10.33%
# 3          12.64%         21.28%         -0.45%         11.70%
# 4          -5.67%         13.21%         -8.50%         17.94%
# 5          -4.57%         -7.72%        -10.67%         19.51%
# 6          -5.29%         47.52%         43.58%         79.69%
# 7         -20.92%         -4.06%         22.79%         73.10%
# 8          -8.95%         14.41%         48.03%        139.50%
# 9          -4.71%          9.05%         -9.10%         12.76%
# 10        -18.00%        -26.43%        -15.80%         59.47%
